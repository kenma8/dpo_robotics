# %%
import pickle

# %%
import pickle

with open("collect_human_preferences/preferences/generated_first_500_dpo.pkl", "rb") as f:
    data = pickle.load(f)

# %%
print(type(data))
# Out:
# <class 'list'>

# %%
data[0]
# Out:
# {'chosen_obs': array([[ 1.40410778,  0.99070877, -0.00673499, ...,  0.        ,
#           0.        ,  0.        ],
#         [ 1.40259507,  0.99990276, -0.00490285, ...,  0.        ,
#           0.        ,  0.        ],
#         [ 1.39711714,  0.99968072, -0.00532562, ...,  0.        ,
#           0.        ,  0.        ],
#         ...,
#         [ 1.26229701,  0.76667481, -0.15848294, ...,  0.        ,
#           0.        ,  0.        ],
#         [ 1.24958722,  0.79599401, -0.13659673, ...,  0.        ,
#           0.        ,  0.        ],
#         [ 1.24603235,  0.81918124, -0.12935453, ...,  0.        ,
#           0.        ,  0.        ]]),
#  'chosen_act': array([[ 0.29067823,  0.27337825, -0.16007656, ..., -0.33554277,
#          -0.29940102,  0.36543298],
#         [ 0.4       ,  0.30475098,  0.20280951, ..., -0.2302762 ,
#          -0.37462372,  0.3775775 ],
#         [ 0.39213732,  0.3363251 ,  0.06645641, ..., -0.28005004,
#          -0.31128985,  0.4       ],
# ...
